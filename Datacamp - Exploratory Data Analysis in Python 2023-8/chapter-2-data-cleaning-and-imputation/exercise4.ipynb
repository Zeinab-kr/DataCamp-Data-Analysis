# %% [markdown]
# #  Finding the number of unique values
#
# ##  Assignment
#
# You would like to practice some of the categorical data manipulation and analysis skills that you've just seen. To help identify which data could be reformatted to extract value, you are going to find out which non-numeric columns in the `planes` dataset have a large number of unique values.
#
# `pandas` has been imported for you as `pd`, and the dataset has been stored as `planes`.
#
# ##  Pre exercise code
#
# ```
# import pandas as pd
# planes = pd.read_csv("https://assets.datacamp.com/production/repositories/6180/datasets/95900664a952fb60b2dd7ea0499ad3e0e20a62f0/planes_end_ex_2.4.csv")
# planes.drop(columns=["Arrival_Time"], inplace=True)
# ```
#
#
#
# ##  Instructions
#
# - Filter `planes` for columns that are of `"object"` data type.
# - Loop through the columns in the dataset.
# - Add the column iterator to the print statement, then call the function to return the number of unique values in the column.

# %%
import pandas as pd
planes = pd.read_csv("https://assets.datacamp.com/production/repositories/6180/datasets/95900664a952fb60b2dd7ea0499ad3e0e20a62f0/planes_end_ex_2.4.csv")
planes.drop(columns=["Arrival_Time"], inplace=True)

# %%
planes.head(1)
# Out:
#        Airline Date_of_Journey Source Destination                  Route  \
# 0  Jet Airways       9/06/2019  Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time Duration Total_Stops Additional_Info    Price
# 0    09:25      19h     2 stops         No info  13882.0

# %%
planes.select_dtypes('object')
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 0     Jet Airways       9/06/2019     Delhi      Cochin
# 1          IndiGo      12/05/2019   Kolkata    Banglore
# 2          IndiGo      01/03/2019  Banglore   New Delhi
# 3        SpiceJet      24/06/2019   Kolkata    Banglore
# 4     Jet Airways      12/03/2019  Banglore   New Delhi
# ...           ...             ...       ...         ...
# 8503     SpiceJet      21/05/2019  Banglore       Delhi
# 8504     Air Asia       9/04/2019   Kolkata    Banglore
# 8505    Air India      27/04/2019   Kolkata    Banglore
# 8506      Vistara      01/03/2019  Banglore   New Delhi
# 8507    Air India       9/05/2019     Delhi      Cochin
#
#                       Route Dep_Time Duration Total_Stops  \
# 0     DEL → LKO → BOM → COK    09:25      19h     2 stops
# 1           CCU → NAG → BLR    18:05   5h 25m      1 stop
# 2           BLR → NAG → DEL    16:50   4h 45m      1 stop
# 3                 CCU → BLR    09:00   2h 25m    non-stop
# 4           BLR → BOM → DEL    18:55  15h 30m      1 stop
# ...                     ...      ...      ...         ...
# 8503              BLR → DEL    05:55   2h 40m    non-stop
# 8504              CCU → BLR    19:55   2h 30m    non-stop
# 8505              CCU → BLR    20:45   2h 35m    non-stop
# 8506              BLR → DEL    11:30   2h 40m    non-stop
# 8507  DEL → GOI → BOM → COK    10:55   8h 20m     2 stops
#
#                    Additional_Info
# 0                          No info
# 1                          No info
# 2                          No info
# 3                          No info
# 4      In-flight meal not included
# ...                            ...
# 8503  No check-in baggage included
# 8504                       No info
# 8505                       No info
# 8506                       No info
# 8507                       No info
#
# [8508 rows x 9 columns]

# %%
for col in planes.columns:
    print(col, planes[col].nunique(), sep=': ')
# Out:
# Airline: 8
# Date_of_Journey: 44
# Source: 5
# Destination: 6
# Route: 122
# Dep_Time: 218
# Duration: 362
# Total_Stops: 5
# Additional_Info: 9
# Price: 1623
