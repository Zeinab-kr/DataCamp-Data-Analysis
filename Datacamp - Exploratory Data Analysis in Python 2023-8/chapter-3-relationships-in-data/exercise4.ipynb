# %% [markdown]
# #  Interpreting a heatmap
#
# ##  Assignment
#
# Which of the below statements is **correct** regarding the relationships between variables in the `divorce` DataFrame?
#
# The `divorce` DataFrame has been loaded for you so that you can explore it in the shell. `pandas` has been loaded as `pd`, `matplotlib.pyplot` has been loaded as `plt`, and Seaborn has been loaded as `sns`.
#
# ##  Pre exercise code
#
# ```
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd
# divorce = pd.read_csv("https://assets.datacamp.com/production/repositories/6180/datasets/a200990873d84f5beec93aab5fa0a9b8f93bd71a/divorce.csv", parse_dates=["divorce_date", "dob_man", "dob_woman", "marriage_date"])
# divorce["marriage_year"] = divorce["marriage_date"].dt.year
# divorce["marriage_month"] = divorce["marriage_date"].dt.month
# ```

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
divorce = pd.read_csv("divorce.csv", parse_dates=["divorce_date", "dob_man", "dob_woman", "marriage_date"])
divorce["marriage_year"] = divorce["marriage_date"].dt.year
divorce["marriage_month"] = divorce["marriage_date"].dt.month

# %%
divorce.head(1)
# Out:
#   divorce_date    dob_man education_man  income_man  dob_woman  \
# 0   2006-09-06 1975-12-18     Secondary      2000.0 1983-08-01
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids  \
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
#
#    marriage_year  marriage_month
# 0           2000               6

# %% [markdown]
# ##  Answers
# 1. `marriage_duration` is strongly positively correlated with `marriage_month`.
# 1. The correlation between `num_kids` and `income_man` is stronger than the correlation between `num_kids` and `marriage_duration`.
# 1. A later `marriage_year` causes a lower number of children, represented by `num_kids`.
# 1. A later `marriage_year` is correlated with having fewer children.

# %%
sns.heatmap(divorce.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >
