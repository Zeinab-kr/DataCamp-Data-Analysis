# %% [markdown]
# #  Is systematic sampling OK?
#
# ##  Assignment
#
# Systematic sampling has a problem: if the data has been sorted, or there is some sort of pattern or meaning behind the row order, then the resulting sample may not be representative of the whole population. The problem can be solved by shuffling the rows, but then systematic sampling is equivalent to simple random sampling.
#
# Here you'll look at how to determine whether or not there is a problem.
#
# `attrition_pop` is available; `pandas`  is loaded as `pd`, and `matplotlib.pyplot` as `plt`.
#
# ##  Pre exercise code
#
# ```
# import pandas as pd
# import matplotlib.pyplot as plt
# attrition_pop = pd.read_feather(
#   path = "/usr/local/share/datasets/attrition.feather"
# )
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
attrition_pop = pd.read_feather(
  path = "attrition.feather"
)

# %%
attrition_pop.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate            Department  \
# 0   21        0.0      Travel_Rarely        391  Research_Development
# 1   19        1.0      Travel_Rarely        528                 Sales
# 2   18        1.0      Travel_Rarely        230  Research_Development
# 3   18        0.0      Travel_Rarely        812                 Sales
# 4   18        1.0  Travel_Frequently       1306                 Sales
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                15        College  Life_Sciences                    High
# 1                22  Below_College      Marketing               Very_High
# 2                 3       Bachelor  Life_Sciences                    High
# 3                10       Bachelor        Medical               Very_High
# 4                 5       Bachelor      Marketing                  Medium
#
#    Gender  ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 0    Male  ...          Excellent                Very_High                 0
# 1    Male  ...          Excellent                Very_High                 0
# 2    Male  ...          Excellent                     High                 0
# 3  Female  ...          Excellent                      Low                 0
# 4    Male  ...          Excellent                Very_High                 0
#
#   TotalWorkingYears TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 0                     6          Better               0
# 1                 0                     2            Good               0
# 2                 0                     2          Better               0
# 3                 0                     2          Better               0
# 4                 0                     3          Better               0
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   0                        0                    0
# 1                   0                        0                    0
# 2                   0                        0                    0
# 3                   0                        0                    0
# 4                   0                        0                    0
#
# [5 rows x 31 columns]

# %% [markdown]
# ##  Instructions
#
# - Add an index column to `attrition_pop`, assigning the result to `attrition_pop_id`.
# - Create a scatter plot of `YearsAtCompany` versus `index` for `attrition_pop_id` using pandas `.plot()`.

# %%
attrition_pop_id = attrition_pop.reset_index()
attrition_pop_id.head()
# Out:
#    index  Age  Attrition     BusinessTravel  DailyRate            Department  \
# 0      0   21        0.0      Travel_Rarely        391  Research_Development
# 1      1   19        1.0      Travel_Rarely        528                 Sales
# 2      2   18        1.0      Travel_Rarely        230  Research_Development
# 3      3   18        0.0      Travel_Rarely        812                 Sales
# 4      4   18        1.0  Travel_Frequently       1306                 Sales
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                15        College  Life_Sciences                    High
# 1                22  Below_College      Marketing               Very_High
# 2                 3       Bachelor  Life_Sciences                    High
# 3                10       Bachelor        Medical               Very_High
# 4                 5       Bachelor      Marketing                  Medium
#
#    ... PerformanceRating  RelationshipSatisfaction StockOptionLevel  \
# 0  ...         Excellent                 Very_High                0
# 1  ...         Excellent                 Very_High                0
# 2  ...         Excellent                      High                0
# 3  ...         Excellent                       Low                0
# 4  ...         Excellent                 Very_High                0
#
#    TotalWorkingYears TrainingTimesLastYear WorkLifeBalance YearsAtCompany  \
# 0                  0                     6          Better              0
# 1                  0                     2            Good              0
# 2                  0                     2          Better              0
# 3                  0                     2          Better              0
# 4                  0                     3          Better              0
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   0                        0                     0
# 1                   0                        0                     0
# 2                   0                        0                     0
# 3                   0                        0                     0
# 4                   0                        0                     0
#
# [5 rows x 32 columns]

# %%
attrition_pop_id.plot(kind='scatter', x='index', y='YearsAtCompany')
# Out:
# <Axes: xlabel='index', ylabel='YearsAtCompany'>

# %% [markdown]
# - Randomly shuffle the rows of `attrition_pop`.
# - Reset the row indexes, and add an index column to `attrition_pop`.
# - Repeat the scatter plot of `YearsAtCompany` versus `index`, this time using `attrition_shuffled`.

# %%
attrition_shuffled = attrition_pop.sample(frac=1).reset_index(drop=True).reset_index()
attrition_shuffled.head()
# Out:
#    index  Age  Attrition     BusinessTravel  DailyRate            Department  \
# 0      0   35        0.0      Travel_Rarely        607  Research_Development
# 1      1   44        0.0      Travel_Rarely       1099                 Sales
# 2      2   39        0.0  Travel_Frequently       1218  Research_Development
# 3      3   51        0.0      Travel_Rarely       1405  Research_Development
# 4      4   43        0.0  Travel_Frequently       1001  Research_Development
#
#    DistanceFromHome      Education    EducationField EnvironmentSatisfaction  \
# 0                 9       Bachelor     Life_Sciences               Very_High
# 1                 5       Bachelor         Marketing                  Medium
# 2                 1  Below_College     Life_Sciences                  Medium
# 3                11        College  Technical_Degree               Very_High
# 4                 9         Doctor           Medical               Very_High
#
#    ... PerformanceRating  RelationshipSatisfaction StockOptionLevel  \
# 0  ...       Outstanding                    Medium                1
# 1  ...         Excellent                      High                1
# 2  ...         Excellent                      High                1
# 3  ...         Excellent                    Medium                0
# 4  ...         Excellent                    Medium                1
#
#    TotalWorkingYears TrainingTimesLastYear WorkLifeBalance YearsAtCompany  \
# 0                 17                     2          Better             17
# 1                 26                     5          Better             22
# 2                 21                     3          Better             21
# 3                 29                     1            Good              5
# 4                 10                     3          Better              8
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  14                        5                    15
# 1                   9                        3                    10
# 2                   8                        1                     6
# 3                   2                        0                     3
# 4                   7                        4                     7
#
# [5 rows x 32 columns]

# %%
attrition_shuffled.plot(kind='scatter', x='index', y='YearsAtCompany')
# Out:
# <Axes: xlabel='index', ylabel='YearsAtCompany'>
